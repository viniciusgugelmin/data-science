# %% [markdown]
# # Configuração de ambiente

# %% [markdown]
# Importação das bibliotecas:
# - Pandas: para manipulação de dados através do alias "pd"
# - Google Colab: para manipulação de arquivos no Google Drive
#
# E execução do comando "%matplotlib inline" para que os gráficos sejam exibidos no notebook logo abaixo da célula de código que os gerou.

# %%
import pandas as pd
from google.colab import drive

# %matplotlib inline

# %% [markdown]
# Carregamento do Drive para que o notebook possa acessar os arquivos do Google Drive e com o parâmetro "force_remount=True" para que o Drive seja montado a cada execução do notebook.

# %%
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Leitura e visualização do dataset
#
# Leitura do arquivo "dataset.csv" através da função "read_csv" do Pandas e armazenamento do resultado na variável "df". Uso do parâmetro "sep" para informar qual o separador de colunas do arquivo e do parâmetro "encoding" para informar qual o tipo de codificação do arquivo.

# %%
csv_url = "https://github.com/viniciusgugelmin/data-science/blob/main/projects/base_de_despesas/data/dataset.csv?raw=true"

df = pd.read_csv(csv_url, sep=';', encoding='iso-8859-1', low_memory=False)

# %% [markdown]
# Atribuição do limite na exibição do dataset para 50 colunas e 20 linhas, afim de conseguir visualizar melhor os dados.

# %%
pd.set_option('display.max_columns', 50)
pd.set_option('display.max_rows', 20)

# %% [markdown]
# Exibição das 5 primeiras linhas do DataFrame através da função "head" do Pandas para verificar se o arquivo foi carregado corretamente e ter uma ideia do que ele contém.

# %%
df.head()
# Out:
#    ANO_EMPENHO  DT_EMPENHO  CD_FONTE  \
# 0  -----------  ----------  --------
# 1         2022  2022-06-09   098
# 2         2022  2022-06-09   098
# 3         2022  2022-06-23   024
# 4         2022  2022-06-23   024
#
#                                             DS_FONTE  CD_FUNCAO  \
# 0                                           --------  ---------
# 1  Recursos Próprios do Fundo Municipal de Apoio ...         08
# 2  Recursos Próprios do Fundo Municipal de Apoio ...         08
# 3  Recursos Próprios do Fundo Municipal de Habita...         16
# 4  Recursos Próprios do Fundo Municipal de Habita...         16
#
#             DS_FUNCAO  CD_PROGRAMA                           DS_PROGRAMA  \
# 0           ---------  -----------                           -----------
# 1  ASSISTÊNCIA SOCIAL         0001  PROGRAMA VIVA CURITIBA QUE NÃO DORME
# 2  ASSISTÊNCIA SOCIAL         0001  PROGRAMA VIVA CURITIBA QUE NÃO DORME
# 3           HABITAÇÃO         0002         PROGRAMA VIVA CURITIBA CIDADÃ
# 4           HABITAÇÃO         0002         PROGRAMA VIVA CURITIBA CIDADÃ
#
#    CD_ACAO                                            DS_ACAO  CD_SUBELEMENTO  \
# 0  -------                                            -------  --------------
# 1     2011  DESENVOLVIMENTO E EXECUÇÃO DE AÇÕES DE ATENDIM...              14
# 2     2011  DESENVOLVIMENTO E EXECUÇÃO DE AÇÕES DE ATENDIM...              14
# 3     2066  MANUTENÇÃO E EXECUÇÃO DOS SERVIÇOS TÉCNICOS, A...               5
# 4     2066  MANUTENÇÃO E EXECUÇÃO DOS SERVIÇOS TÉCNICOS, A...               5
#
#                                       DS_SUBELEMENTO  CD_ORGAO  \
# 0                                     --------------  --------
# 1  LOCAÇÃO DE BENS MÓVEIS E OUTRAS NATUREZAS E IN...        37
# 2  LOCAÇÃO DE BENS MÓVEIS E OUTRAS NATUREZAS E IN...        37
# 3                    SERVIÇOS TÉCNICOS PROFISSIONAIS        49
# 4                    SERVIÇOS TÉCNICOS PROFISSIONAIS        49
#
#                                            DS_ORGAO  CD_DESPESA  \
# 0                                          --------  ----------
# 1            FUNDO MUNICIPAL DE APOIO AO DEFICIENTE      339039
# 2            FUNDO MUNICIPAL DE APOIO AO DEFICIENTE      339039
# 3  FUNDO MUNICIPAL DE HABITAÇÃO DE INTERESSE SOCIAL      339039
# 4  FUNDO MUNICIPAL DE HABITAÇÃO DE INTERESSE SOCIAL      339039
#
#                                        DS_DESPESA  CODIGO_DESPESA_GRUPO  \
# 0                                      ----------  --------------------
# 1  OUTROS SERVIÇOS DE TERCEIROS - PESSOA JURÍDICA                     3
# 2  OUTROS SERVIÇOS DE TERCEIROS - PESSOA JURÍDICA                     3
# 3  OUTROS SERVIÇOS DE TERCEIROS - PESSOA JURÍDICA                     3
# 4  OUTROS SERVIÇOS DE TERCEIROS - PESSOA JURÍDICA                     3
#
#                     DS_GRUPO  CODIGO_DESPESA_MODALIDADE       DS_MODALIDADE  \
# 0                   --------  -------------------------       -------------
# 1  Outras Despesas Correntes                         90  Aplicações Diretas
# 2  Outras Despesas Correntes                         90  Aplicações Diretas
# 3  Outras Despesas Correntes                         90  Aplicações Diretas
# 4  Outras Despesas Correntes                         90  Aplicações Diretas
#
#    CODIGO_DESPESA_ELEMENTO                                     DS_ELEMENTO  \
# 0  -----------------------                                     -----------
# 1                       39  Outros Serviços de Terceiros - Pessoa Jurídica
# 2                       39  Outros Serviços de Terceiros - Pessoa Jurídica
# 3                       39  Outros Serviços de Terceiros - Pessoa Jurídica
# 4                       39  Outros Serviços de Terceiros - Pessoa Jurídica
#
#              CPF_CNPJ  NR_EMPENHO                 LICITACAO  VL_EMPENHADO  \
# 0            --------  ----------                 ---------  ------------
# 1  33038864000151               5    PE 186/2021 SMAP/SMELJ       5103,00
# 2  33038864000151               5    PE 186/2021 SMAP/SMELJ       5103,00
# 3  03864060000140               6  PE 4/2020 COHAB-CT/FMHIS       1665,88
# 4  03864060000140               6  PE 4/2020 COHAB-CT/FMHIS       1665,88
#
#    CD_ITEM                                            DS_ITEM  DS_UNIDADE  \
# 0  -------                                            -------  ----------
# 1        3  BRINQUEDO INFLÁVEL, LOCAÇÃO,  PULA PULA, CASTE...         MO
# 2        5      BRINQUEDO,  PISCINA DE BOLINHAS CONVENCIONAL,         MO
# 3      NaN                                                NaN         NaN
# 4      NaN                                                NaN         NaN
#
#    QUANTIDADE  VL_PRECO_UNITARIO   VL_TOTAL    PROTOCOLOSUP  \
# 0  ----------  -----------------   --------    ------------
# 1      3,0000           705,0000  2115,0000             NaN
# 2      2,0000           402,0000   804,0000             NaN
# 3         NaN                NaN        NaN  01-122405/2022
# 4         NaN                NaN        NaN  01-122405/2022
#
#               DT_TRANSACAO    NR_PARCELA             TRANSACAO  VL_LIQUIDADO  \
# 0             ------------  ------------          ------------  ------------
# 1                      NaN           NaN                   NaN           NaN
# 2                      NaN           NaN                   NaN           NaN
# 3  2022-07-22 00:00:00.000             1    Anulado de Empenho          0,00
# 4  2022-07-14 00:00:00.000             1  Pagamento de Empenho          0,00
#
#    VL_DEVOLVIDO  VL_ANULADO  VL_PAGO  VL_CONSIGNADO
# 0  ------------  ----------  -------  -------------
# 1           NaN         NaN      NaN            NaN
# 2           NaN         NaN      NaN            NaN
# 3          0,00      532,44     0,00           0,00
# 4          0,00        0,00  1133,44           0,00

# %% [markdown]
# # Processo inicial de limpeza

# %% [markdown]
# Exclusão da coluna de índice 0 do DataFrame através da função "drop" do Pandas, pois ela é composta apenas por traços e não possui nenhum valor relevante além de separar as linhas do cabeçalho visualmente.

# %%
df = df.drop(0)
df.head()
# Out:
#   ANO_EMPENHO  DT_EMPENHO CD_FONTE  \
# 1        2022  2022-06-09  098
# 2        2022  2022-06-09  098
# 3        2022  2022-06-23  024
# 4        2022  2022-06-23  024
# 5        2022  2022-06-23  024
#
#                                             DS_FONTE CD_FUNCAO  \
# 1  Recursos Próprios do Fundo Municipal de Apoio ...        08
# 2  Recursos Próprios do Fundo Municipal de Apoio ...        08
# 3  Recursos Próprios do Fundo Municipal de Habita...        16
# 4  Recursos Próprios do Fundo Municipal de Habita...        16
# 5  Recursos Próprios do Fundo Municipal de Habita...        16
#
#             DS_FUNCAO CD_PROGRAMA                           DS_PROGRAMA  \
# 1  ASSISTÊNCIA SOCIAL        0001  PROGRAMA VIVA CURITIBA QUE NÃO DORME
# 2  ASSISTÊNCIA SOCIAL        0001  PROGRAMA VIVA CURITIBA QUE NÃO DORME
# 3           HABITAÇÃO        0002         PROGRAMA VIVA CURITIBA CIDADÃ
# 4           HABITAÇÃO        0002         PROGRAMA VIVA CURITIBA CIDADÃ
# 5           HABITAÇÃO        0002         PROGRAMA VIVA CURITIBA CIDADÃ
#
#   CD_ACAO                                            DS_ACAO CD_SUBELEMENTO  \
# 1    2011  DESENVOLVIMENTO E EXECUÇÃO DE AÇÕES DE ATENDIM...             14
# 2    2011  DESENVOLVIMENTO E EXECUÇÃO DE AÇÕES DE ATENDIM...             14
# 3    2066  MANUTENÇÃO E EXECUÇÃO DOS SERVIÇOS TÉCNICOS, A...              5
# 4    2066  MANUTENÇÃO E EXECUÇÃO DOS SERVIÇOS TÉCNICOS, A...              5
# 5    2066  MANUTENÇÃO E EXECUÇÃO DOS SERVIÇOS TÉCNICOS, A...              5
#
#                                       DS_SUBELEMENTO CD_ORGAO  \
# 1  LOCAÇÃO DE BENS MÓVEIS E OUTRAS NATUREZAS E IN...       37
# 2  LOCAÇÃO DE BENS MÓVEIS E OUTRAS NATUREZAS E IN...       37
# 3                    SERVIÇOS TÉCNICOS PROFISSIONAIS       49
# 4                    SERVIÇOS TÉCNICOS PROFISSIONAIS       49
# 5                    SERVIÇOS TÉCNICOS PROFISSIONAIS       49
#
#                                            DS_ORGAO CD_DESPESA  \
# 1            FUNDO MUNICIPAL DE APOIO AO DEFICIENTE     339039
# 2            FUNDO MUNICIPAL DE APOIO AO DEFICIENTE     339039
# 3  FUNDO MUNICIPAL DE HABITAÇÃO DE INTERESSE SOCIAL     339039
# 4  FUNDO MUNICIPAL DE HABITAÇÃO DE INTERESSE SOCIAL     339039
# 5  FUNDO MUNICIPAL DE HABITAÇÃO DE INTERESSE SOCIAL     339039
#
#                                        DS_DESPESA CODIGO_DESPESA_GRUPO  \
# 1  OUTROS SERVIÇOS DE TERCEIROS - PESSOA JURÍDICA                    3
# 2  OUTROS SERVIÇOS DE TERCEIROS - PESSOA JURÍDICA                    3
# 3  OUTROS SERVIÇOS DE TERCEIROS - PESSOA JURÍDICA                    3
# 4  OUTROS SERVIÇOS DE TERCEIROS - PESSOA JURÍDICA                    3
# 5  OUTROS SERVIÇOS DE TERCEIROS - PESSOA JURÍDICA                    3
#
#                     DS_GRUPO CODIGO_DESPESA_MODALIDADE       DS_MODALIDADE  \
# 1  Outras Despesas Correntes                        90  Aplicações Diretas
# 2  Outras Despesas Correntes                        90  Aplicações Diretas
# 3  Outras Despesas Correntes                        90  Aplicações Diretas
# 4  Outras Despesas Correntes                        90  Aplicações Diretas
# 5  Outras Despesas Correntes                        90  Aplicações Diretas
#
#   CODIGO_DESPESA_ELEMENTO                                     DS_ELEMENTO  \
# 1                      39  Outros Serviços de Terceiros - Pessoa Jurídica
# 2                      39  Outros Serviços de Terceiros - Pessoa Jurídica
# 3                      39  Outros Serviços de Terceiros - Pessoa Jurídica
# 4                      39  Outros Serviços de Terceiros - Pessoa Jurídica
# 5                      39  Outros Serviços de Terceiros - Pessoa Jurídica
#
#              CPF_CNPJ NR_EMPENHO                 LICITACAO VL_EMPENHADO  \
# 1  33038864000151              5    PE 186/2021 SMAP/SMELJ      5103,00
# 2  33038864000151              5    PE 186/2021 SMAP/SMELJ      5103,00
# 3  03864060000140              6  PE 4/2020 COHAB-CT/FMHIS      1665,88
# 4  03864060000140              6  PE 4/2020 COHAB-CT/FMHIS      1665,88
# 5  03864060000140              6  PE 4/2020 COHAB-CT/FMHIS      1665,88
#
#   CD_ITEM                                            DS_ITEM DS_UNIDADE  \
# 1       3  BRINQUEDO INFLÁVEL, LOCAÇÃO,  PULA PULA, CASTE...        MO
# 2       5      BRINQUEDO,  PISCINA DE BOLINHAS CONVENCIONAL,        MO
# 3     NaN                                                NaN        NaN
# 4     NaN                                                NaN        NaN
# 5     NaN                                                NaN        NaN
#
#   QUANTIDADE VL_PRECO_UNITARIO   VL_TOTAL    PROTOCOLOSUP  \
# 1     3,0000          705,0000  2115,0000             NaN
# 2     2,0000          402,0000   804,0000             NaN
# 3        NaN               NaN        NaN  01-122405/2022
# 4        NaN               NaN        NaN  01-122405/2022
# 5        NaN               NaN        NaN  01-122405/2022
#
#               DT_TRANSACAO NR_PARCELA              TRANSACAO VL_LIQUIDADO  \
# 1                      NaN        NaN                    NaN          NaN
# 2                      NaN        NaN                    NaN          NaN
# 3  2022-07-22 00:00:00.000          1     Anulado de Empenho         0,00
# 4  2022-07-14 00:00:00.000          1   Pagamento de Empenho         0,00
# 5  2022-07-13 00:00:00.000          1  Liquidação de Empenho      1133,44
#
#   VL_DEVOLVIDO VL_ANULADO  VL_PAGO VL_CONSIGNADO
# 1          NaN        NaN      NaN           NaN
# 2          NaN        NaN      NaN           NaN
# 3         0,00     532,44     0,00          0,00
# 4         0,00       0,00  1133,44          0,00
# 5         0,00       0,00     0,00          0,00

# %% [markdown]
# Reset do index do DataFrame através da função "reset_index" do Pandas para que o index seja redefinido a partir do 0 e utilização do parâmetro "drop=True" para que a coluna de índice antiga seja excluída.

# %%
df = df.reset_index(drop=True)
df.head()
# Out:
#   ANO_EMPENHO  DT_EMPENHO CD_FONTE  \
# 0        2022  2022-06-09  098
# 1        2022  2022-06-09  098
# 2        2022  2022-06-23  024
# 3        2022  2022-06-23  024
# 4        2022  2022-06-23  024
#
#                                             DS_FONTE CD_FUNCAO  \
# 0  Recursos Próprios do Fundo Municipal de Apoio ...        08
# 1  Recursos Próprios do Fundo Municipal de Apoio ...        08
# 2  Recursos Próprios do Fundo Municipal de Habita...        16
# 3  Recursos Próprios do Fundo Municipal de Habita...        16
# 4  Recursos Próprios do Fundo Municipal de Habita...        16
#
#             DS_FUNCAO CD_PROGRAMA                           DS_PROGRAMA  \
# 0  ASSISTÊNCIA SOCIAL        0001  PROGRAMA VIVA CURITIBA QUE NÃO DORME
# 1  ASSISTÊNCIA SOCIAL        0001  PROGRAMA VIVA CURITIBA QUE NÃO DORME
# 2           HABITAÇÃO        0002         PROGRAMA VIVA CURITIBA CIDADÃ
# 3           HABITAÇÃO        0002         PROGRAMA VIVA CURITIBA CIDADÃ
# 4           HABITAÇÃO        0002         PROGRAMA VIVA CURITIBA CIDADÃ
#
#   CD_ACAO                                            DS_ACAO CD_SUBELEMENTO  \
# 0    2011  DESENVOLVIMENTO E EXECUÇÃO DE AÇÕES DE ATENDIM...             14
# 1    2011  DESENVOLVIMENTO E EXECUÇÃO DE AÇÕES DE ATENDIM...             14
# 2    2066  MANUTENÇÃO E EXECUÇÃO DOS SERVIÇOS TÉCNICOS, A...              5
# 3    2066  MANUTENÇÃO E EXECUÇÃO DOS SERVIÇOS TÉCNICOS, A...              5
# 4    2066  MANUTENÇÃO E EXECUÇÃO DOS SERVIÇOS TÉCNICOS, A...              5
#
#                                       DS_SUBELEMENTO CD_ORGAO  \
# 0  LOCAÇÃO DE BENS MÓVEIS E OUTRAS NATUREZAS E IN...       37
# 1  LOCAÇÃO DE BENS MÓVEIS E OUTRAS NATUREZAS E IN...       37
# 2                    SERVIÇOS TÉCNICOS PROFISSIONAIS       49
# 3                    SERVIÇOS TÉCNICOS PROFISSIONAIS       49
# 4                    SERVIÇOS TÉCNICOS PROFISSIONAIS       49
#
#                                            DS_ORGAO CD_DESPESA  \
# 0            FUNDO MUNICIPAL DE APOIO AO DEFICIENTE     339039
# 1            FUNDO MUNICIPAL DE APOIO AO DEFICIENTE     339039
# 2  FUNDO MUNICIPAL DE HABITAÇÃO DE INTERESSE SOCIAL     339039
# 3  FUNDO MUNICIPAL DE HABITAÇÃO DE INTERESSE SOCIAL     339039
# 4  FUNDO MUNICIPAL DE HABITAÇÃO DE INTERESSE SOCIAL     339039
#
#                                        DS_DESPESA CODIGO_DESPESA_GRUPO  \
# 0  OUTROS SERVIÇOS DE TERCEIROS - PESSOA JURÍDICA                    3
# 1  OUTROS SERVIÇOS DE TERCEIROS - PESSOA JURÍDICA                    3
# 2  OUTROS SERVIÇOS DE TERCEIROS - PESSOA JURÍDICA                    3
# 3  OUTROS SERVIÇOS DE TERCEIROS - PESSOA JURÍDICA                    3
# 4  OUTROS SERVIÇOS DE TERCEIROS - PESSOA JURÍDICA                    3
#
#                     DS_GRUPO CODIGO_DESPESA_MODALIDADE       DS_MODALIDADE  \
# 0  Outras Despesas Correntes                        90  Aplicações Diretas
# 1  Outras Despesas Correntes                        90  Aplicações Diretas
# 2  Outras Despesas Correntes                        90  Aplicações Diretas
# 3  Outras Despesas Correntes                        90  Aplicações Diretas
# 4  Outras Despesas Correntes                        90  Aplicações Diretas
#
#   CODIGO_DESPESA_ELEMENTO                                     DS_ELEMENTO  \
# 0                      39  Outros Serviços de Terceiros - Pessoa Jurídica
# 1                      39  Outros Serviços de Terceiros - Pessoa Jurídica
# 2                      39  Outros Serviços de Terceiros - Pessoa Jurídica
# 3                      39  Outros Serviços de Terceiros - Pessoa Jurídica
# 4                      39  Outros Serviços de Terceiros - Pessoa Jurídica
#
#              CPF_CNPJ NR_EMPENHO                 LICITACAO VL_EMPENHADO  \
# 0  33038864000151              5    PE 186/2021 SMAP/SMELJ      5103,00
# 1  33038864000151              5    PE 186/2021 SMAP/SMELJ      5103,00
# 2  03864060000140              6  PE 4/2020 COHAB-CT/FMHIS      1665,88
# 3  03864060000140              6  PE 4/2020 COHAB-CT/FMHIS      1665,88
# 4  03864060000140              6  PE 4/2020 COHAB-CT/FMHIS      1665,88
#
#   CD_ITEM                                            DS_ITEM DS_UNIDADE  \
# 0       3  BRINQUEDO INFLÁVEL, LOCAÇÃO,  PULA PULA, CASTE...        MO
# 1       5      BRINQUEDO,  PISCINA DE BOLINHAS CONVENCIONAL,        MO
# 2     NaN                                                NaN        NaN
# 3     NaN                                                NaN        NaN
# 4     NaN                                                NaN        NaN
#
#   QUANTIDADE VL_PRECO_UNITARIO   VL_TOTAL    PROTOCOLOSUP  \
# 0     3,0000          705,0000  2115,0000             NaN
# 1     2,0000          402,0000   804,0000             NaN
# 2        NaN               NaN        NaN  01-122405/2022
# 3        NaN               NaN        NaN  01-122405/2022
# 4        NaN               NaN        NaN  01-122405/2022
#
#               DT_TRANSACAO NR_PARCELA              TRANSACAO VL_LIQUIDADO  \
# 0                      NaN        NaN                    NaN          NaN
# 1                      NaN        NaN                    NaN          NaN
# 2  2022-07-22 00:00:00.000          1     Anulado de Empenho         0,00
# 3  2022-07-14 00:00:00.000          1   Pagamento de Empenho         0,00
# 4  2022-07-13 00:00:00.000          1  Liquidação de Empenho      1133,44
#
#   VL_DEVOLVIDO VL_ANULADO  VL_PAGO VL_CONSIGNADO
# 0          NaN        NaN      NaN           NaN
# 1          NaN        NaN      NaN           NaN
# 2         0,00     532,44     0,00          0,00
# 3         0,00       0,00  1133,44          0,00
# 4         0,00       0,00     0,00          0,00

# %% [markdown]
# Exibição dos nomes das colunas do DataFrame através da função "columns" do Pandas para visualizar melhor quais colunas são necessárias através do cabeçalho e dicionário de dados incluso na pasta "data" do projeto, e também para verificar se o nome das colunas está legível.

# %%
df.columns
# Out:
# Index(['ANO_EMPENHO', 'DT_EMPENHO', 'CD_FONTE', 'DS_FONTE', 'CD_FUNCAO',
#        'DS_FUNCAO', 'CD_PROGRAMA', 'DS_PROGRAMA', 'CD_ACAO', 'DS_ACAO',
#        'CD_SUBELEMENTO', 'DS_SUBELEMENTO', 'CD_ORGAO', 'DS_ORGAO',
#        'CD_DESPESA', 'DS_DESPESA', 'CODIGO_DESPESA_GRUPO', 'DS_GRUPO',
#        'CODIGO_DESPESA_MODALIDADE', 'DS_MODALIDADE', 'CODIGO_DESPESA_ELEMENTO',
#        'DS_ELEMENTO', 'CPF_CNPJ', 'NR_EMPENHO', 'LICITACAO', 'VL_EMPENHADO',
#        'CD_ITEM', 'DS_ITEM', 'DS_UNIDADE', 'QUANTIDADE', 'VL_PRECO_UNITARIO',
#        'VL_TOTAL', 'PROTOCOLOSUP', 'DT_TRANSACAO', 'NR_PARCELA', 'TRANSACAO',
#        'VL_LIQUIDADO', 'VL_DEVOLVIDO', 'VL_ANULADO', 'VL_PAGO',
#        'VL_CONSIGNADO'],
#       dtype='object')

# %% [markdown]
# Encontramos a possibilidade de remover a coluna "ANO_EMPENHO" pois todos os valores são iguais, e estão presentes na coluna "DT_EMPENHO".
# Vamos remover também todas as colunas que são de código de identificação, pois não são relevantes para a análise.
# Colunas de numeração estão pouco relevantes para a análise, então vamos removê-las também, junto das "DS_GRUPO" e "DS_MODALIDADE", pois já temos a "DS_DEPESA" que detalha mais o tipo da despesa.
# E por fim, vamos remover as colunas que apresentam números de identificação de licitação e protocolo, pois não são relevantes para a análise.
#
# Todas essas remoções serão feitas usando a função drop, e filter para selecionar as colunas que serão removidas através de regex.

# %%
df = df.drop(df.filter(regex='ANO_EMPENHO|CD_|CODIGO_|NR_|LICITACAO|PROTOCOLOSUP|DS_GRUPO|DS_MODALIDADE').columns, axis=1)
df.columns
# Out:
# Index(['DT_EMPENHO', 'DS_FONTE', 'DS_FUNCAO', 'DS_PROGRAMA', 'DS_ACAO',
#        'DS_SUBELEMENTO', 'DS_ORGAO', 'DS_DESPESA', 'DS_ELEMENTO', 'CPF_CNPJ',
#        'VL_EMPENHADO', 'DS_ITEM', 'DS_UNIDADE', 'QUANTIDADE',
#        'VL_PRECO_UNITARIO', 'VL_TOTAL', 'DT_TRANSACAO', 'TRANSACAO',
#        'VL_LIQUIDADO', 'VL_DEVOLVIDO', 'VL_ANULADO', 'VL_PAGO',
#        'VL_CONSIGNADO'],
#       dtype='object')

# %% [markdown]
# Deixaremos legíveis os nomes das colunas, para facilitar a manipulação dos dados.
# Visualizamos previamente uma abreviação de "DS_" que não é relevante, "DT_" que é a data, e "VL_" que é o valor, fazendo então essas substituições para deixar o nome das colunas mais legíveis.
# Encontramos algumas colunas que não expressam muito bem para qual elemento da despesa estão se referindo, então vamos renomeá-las para deixar mais claro.
# Pensando também nisso, vamos renomear a coluna de "CPF_CNPJ" para "DOCUMENTO" para conseguir diferenciar melhor os tipos de documentos em outra coluna que será criada.
#
# Todas essas alterações serão feitas usando a função rename, e columns.str.replace para substituir os nomes das colunas.

# %%
df.columns = df.columns.str.replace('DT_', 'DATA_').str.replace('DS_', '').str.replace('VL_', 'VALOR_')
df.columns = df.columns.str.replace('CPF_CNPJ', 'DOCUMENTO').str.replace('UNIDADE', 'UNIDADE_ITEM').str.replace('QUANTIDADE', 'QUANTIDADE_ITEM').str.replace('DESPESA', 'TIPO').str.replace('DATA_EMPENHO', 'DATA')
df = df.rename(columns={'TRANSACAO': 'STATUS_TRANSACAO'})
df.columns
# Out:
# Index(['DATA', 'FONTE', 'FUNCAO', 'PROGRAMA', 'ACAO', 'SUBELEMENTO', 'ORGAO',
#        'TIPO', 'ELEMENTO', 'DOCUMENTO', 'VALOR_EMPENHADO', 'ITEM',
#        'UNIDADE_ITEM', 'QUANTIDADE_ITEM', 'VALOR_PRECO_UNITARIO',
#        'VALOR_TOTAL', 'DATA_TRANSACAO', 'STATUS_TRANSACAO', 'VALOR_LIQUIDADO',
#        'VALOR_DEVOLVIDO', 'VALOR_ANULADO', 'VALOR_PAGO', 'VALOR_CONSIGNADO'],
#       dtype='object')

# %%
df.head()
# Out:
#          DATA                                              FONTE  \
# 0  2022-06-09  Recursos Próprios do Fundo Municipal de Apoio ...
# 1  2022-06-09  Recursos Próprios do Fundo Municipal de Apoio ...
# 2  2022-06-23  Recursos Próprios do Fundo Municipal de Habita...
# 3  2022-06-23  Recursos Próprios do Fundo Municipal de Habita...
# 4  2022-06-23  Recursos Próprios do Fundo Municipal de Habita...
#
#                FUNCAO                              PROGRAMA  \
# 0  ASSISTÊNCIA SOCIAL  PROGRAMA VIVA CURITIBA QUE NÃO DORME
# 1  ASSISTÊNCIA SOCIAL  PROGRAMA VIVA CURITIBA QUE NÃO DORME
# 2           HABITAÇÃO         PROGRAMA VIVA CURITIBA CIDADÃ
# 3           HABITAÇÃO         PROGRAMA VIVA CURITIBA CIDADÃ
# 4           HABITAÇÃO         PROGRAMA VIVA CURITIBA CIDADÃ
#
#                                                 ACAO  \
# 0  DESENVOLVIMENTO E EXECUÇÃO DE AÇÕES DE ATENDIM...
# 1  DESENVOLVIMENTO E EXECUÇÃO DE AÇÕES DE ATENDIM...
# 2  MANUTENÇÃO E EXECUÇÃO DOS SERVIÇOS TÉCNICOS, A...
# 3  MANUTENÇÃO E EXECUÇÃO DOS SERVIÇOS TÉCNICOS, A...
# 4  MANUTENÇÃO E EXECUÇÃO DOS SERVIÇOS TÉCNICOS, A...
#
#                                          SUBELEMENTO  \
# 0  LOCAÇÃO DE BENS MÓVEIS E OUTRAS NATUREZAS E IN...
# 1  LOCAÇÃO DE BENS MÓVEIS E OUTRAS NATUREZAS E IN...
# 2                    SERVIÇOS TÉCNICOS PROFISSIONAIS
# 3                    SERVIÇOS TÉCNICOS PROFISSIONAIS
# 4                    SERVIÇOS TÉCNICOS PROFISSIONAIS
#
#                                               ORGAO  \
# 0            FUNDO MUNICIPAL DE APOIO AO DEFICIENTE
# 1            FUNDO MUNICIPAL DE APOIO AO DEFICIENTE
# 2  FUNDO MUNICIPAL DE HABITAÇÃO DE INTERESSE SOCIAL
# 3  FUNDO MUNICIPAL DE HABITAÇÃO DE INTERESSE SOCIAL
# 4  FUNDO MUNICIPAL DE HABITAÇÃO DE INTERESSE SOCIAL
#
#                                              TIPO  \
# 0  OUTROS SERVIÇOS DE TERCEIROS - PESSOA JURÍDICA
# 1  OUTROS SERVIÇOS DE TERCEIROS - PESSOA JURÍDICA
# 2  OUTROS SERVIÇOS DE TERCEIROS - PESSOA JURÍDICA
# 3  OUTROS SERVIÇOS DE TERCEIROS - PESSOA JURÍDICA
# 4  OUTROS SERVIÇOS DE TERCEIROS - PESSOA JURÍDICA
#
#                                          ELEMENTO           DOCUMENTO  \
# 0  Outros Serviços de Terceiros - Pessoa Jurídica  33038864000151
# 1  Outros Serviços de Terceiros - Pessoa Jurídica  33038864000151
# 2  Outros Serviços de Terceiros - Pessoa Jurídica  03864060000140
# 3  Outros Serviços de Terceiros - Pessoa Jurídica  03864060000140
# 4  Outros Serviços de Terceiros - Pessoa Jurídica  03864060000140
#
#   VALOR_EMPENHADO                                               ITEM  \
# 0         5103,00  BRINQUEDO INFLÁVEL, LOCAÇÃO,  PULA PULA, CASTE...
# 1         5103,00      BRINQUEDO,  PISCINA DE BOLINHAS CONVENCIONAL,
# 2         1665,88                                                NaN
# 3         1665,88                                                NaN
# 4         1665,88                                                NaN
#
#   UNIDADE_ITEM QUANTIDADE_ITEM VALOR_PRECO_UNITARIO VALOR_TOTAL  \
# 0          MO           3,0000             705,0000   2115,0000
# 1          MO           2,0000             402,0000    804,0000
# 2          NaN             NaN                  NaN         NaN
# 3          NaN             NaN                  NaN         NaN
# 4          NaN             NaN                  NaN         NaN
#
#             DATA_TRANSACAO       STATUS_TRANSACAO VALOR_LIQUIDADO  \
# 0                      NaN                    NaN             NaN
# 1                      NaN                    NaN             NaN
# 2  2022-07-22 00:00:00.000     Anulado de Empenho            0,00
# 3  2022-07-14 00:00:00.000   Pagamento de Empenho            0,00
# 4  2022-07-13 00:00:00.000  Liquidação de Empenho         1133,44
#
#   VALOR_DEVOLVIDO VALOR_ANULADO VALOR_PAGO VALOR_CONSIGNADO
# 0             NaN           NaN        NaN              NaN
# 1             NaN           NaN        NaN              NaN
# 2            0,00        532,44       0,00             0,00
# 3            0,00          0,00    1133,44             0,00
# 4            0,00          0,00       0,00             0,00

# %% [markdown]
# Utilização do método **info** para tentar encontrar valores nulos que não deveriam ser nulos.

# %% [markdown]
# # Processo de limpeza de dados nulos e padronização de dados

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36086 entries, 0 to 36085
# Data columns (total 23 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   DATA                  36086 non-null  object
#  1   FONTE                 36086 non-null  object
#  2   FUNCAO                36086 non-null  object
#  3   PROGRAMA              36086 non-null  object
#  4   ACAO                  36086 non-null  object
#  5   SUBELEMENTO           36086 non-null  object
#  6   ORGAO                 36086 non-null  object
#  7   TIPO                  36086 non-null  object
#  8   ELEMENTO              36086 non-null  object
#  9   DOCUMENTO             36086 non-null  object
#  10  VALOR_EMPENHADO       36086 non-null  object
#  11  ITEM                  9374 non-null   object
#  12  UNIDADE_ITEM          9374 non-null   object
#  13  QUANTIDADE_ITEM       9374 non-null   object
#  14  VALOR_PRECO_UNITARIO  9374 non-null   object
#  15  VALOR_TOTAL           9374 non-null   object
#  16  DATA_TRANSACAO        30884 non-null  object
#  17  STATUS_TRANSACAO      30884 non-null  object
#  18  VALOR_LIQUIDADO       30884 non-null  object
#  19  VALOR_DEVOLVIDO       30884 non-null  object
#  20  VALOR_ANULADO         30884 non-null  object
#  21  VALOR_PAGO            30884 non-null  object
#  22  VALOR_CONSIGNADO      30884 non-null  object
# dtypes: object(23)
# memory usage: 6.3+ MB

# %% [markdown]
# Converção de certas colunas para númerico e data, e preenchimento das mesmas que estão com valores nulos para 0 para não interferir em possíveis cálculos. Foi descoberto também durante a limpeza que os valores de documentos estavam com espaços antes ou/e após os números do mesmo, então se teve o trabalho de retirar estes espaços.

# %%
df_cleaned = df.copy()

df_cleaned['DATA'] = pd.to_datetime(df_cleaned['DATA'], errors="coerce")
df_cleaned['VALOR_EMPENHADO'] = pd.to_numeric(df_cleaned['VALOR_EMPENHADO'].str.replace(",","."), errors="coerce")
df_cleaned['DOCUMENTO'] = df_cleaned['DOCUMENTO'].str.replace(" ", "")

df_cleaned['QUANTIDADE_ITEM'] = pd.to_numeric(df_cleaned['QUANTIDADE_ITEM'].str.replace(",","."), errors="coerce")
df_cleaned['VALOR_PRECO_UNITARIO'] = pd.to_numeric(df_cleaned['VALOR_PRECO_UNITARIO'].str.replace(",","."), errors="coerce")
df_cleaned['VALOR_TOTAL'] = pd.to_numeric(df_cleaned['VALOR_TOTAL'].str.replace(",","."), errors="coerce")
df_cleaned['VALOR_LIQUIDADO'] = pd.to_numeric(df_cleaned['VALOR_LIQUIDADO'].str.replace(",","."), errors="coerce")
df_cleaned['VALOR_DEVOLVIDO'] = pd.to_numeric(df_cleaned['VALOR_DEVOLVIDO'].str.replace(",","."), errors="coerce")
df_cleaned['VALOR_ANULADO'] = pd.to_numeric(df_cleaned['VALOR_ANULADO'].str.replace(",","."), errors="coerce")
df_cleaned['VALOR_PAGO'] = pd.to_numeric(df_cleaned['VALOR_PAGO'].str.replace(",","."), errors="coerce")
df_cleaned['VALOR_CONSIGNADO'] = pd.to_numeric(df_cleaned['VALOR_CONSIGNADO'].str.replace(",","."), errors="coerce")

df_cleaned['QUANTIDADE_ITEM'] = df_cleaned['QUANTIDADE_ITEM'].fillna(0)
df_cleaned['VALOR_PRECO_UNITARIO'] = df_cleaned['VALOR_PRECO_UNITARIO'].fillna(0)
df_cleaned['VALOR_TOTAL'] = df_cleaned['VALOR_TOTAL'].fillna(0)
df_cleaned['VALOR_LIQUIDADO'] = df_cleaned['VALOR_LIQUIDADO'].fillna(0)
df_cleaned['VALOR_DEVOLVIDO'] = df_cleaned['VALOR_DEVOLVIDO'].fillna(0)
df_cleaned['VALOR_ANULADO'] = df_cleaned['VALOR_ANULADO'].fillna(0)
df_cleaned['VALOR_PAGO'] = df_cleaned['VALOR_PAGO'].fillna(0)
df_cleaned['VALOR_CONSIGNADO'] = df_cleaned['VALOR_CONSIGNADO'].fillna(0)

df_cleaned
# Out:
#             DATA                                              FONTE  \
# 0     2022-06-09  Recursos Próprios do Fundo Municipal de Apoio ...
# 1     2022-06-09  Recursos Próprios do Fundo Municipal de Apoio ...
# 2     2022-06-23  Recursos Próprios do Fundo Municipal de Habita...
# 3     2022-06-23  Recursos Próprios do Fundo Municipal de Habita...
# 4     2022-06-23  Recursos Próprios do Fundo Municipal de Habita...
# ...          ...                                                ...
# 36081 2022-08-31  Programa Dinheiro Direto na Escola - PDDE - Ed...
# 36082 2022-08-31  Programa Dinheiro Direto na Escola - PDDE - Ed...
# 36083 2022-08-31  Programa Dinheiro Direto na Escola - PDDE - Ed...
# 36084 2022-08-31                       Recursos Ordinários (Livres)
# 36085 2022-08-31     5% Sobre Transferências Constitucionais FUNDEB
#
#                    FUNCAO                              PROGRAMA  \
# 0      ASSISTÊNCIA SOCIAL  PROGRAMA VIVA CURITIBA QUE NÃO DORME
# 1      ASSISTÊNCIA SOCIAL  PROGRAMA VIVA CURITIBA QUE NÃO DORME
# 2               HABITAÇÃO         PROGRAMA VIVA CURITIBA CIDADÃ
# 3               HABITAÇÃO         PROGRAMA VIVA CURITIBA CIDADÃ
# 4               HABITAÇÃO         PROGRAMA VIVA CURITIBA CIDADÃ
# ...                   ...                                   ...
# 36081            EDUCAÇÃO         PROGRAMA VIVA CURITIBA CIDADÃ
# 36082            EDUCAÇÃO         PROGRAMA VIVA CURITIBA CIDADÃ
# 36083            EDUCAÇÃO         PROGRAMA VIVA CURITIBA CIDADÃ
# 36084       ADMINISTRAÇÃO   PROGRAMA VIVA CURITIBA TRANSPARENTE
# 36085            EDUCAÇÃO         PROGRAMA VIVA CURITIBA CIDADÃ
#
#                                                     ACAO  \
# 0      DESENVOLVIMENTO E EXECUÇÃO DE AÇÕES DE ATENDIM...
# 1      DESENVOLVIMENTO E EXECUÇÃO DE AÇÕES DE ATENDIM...
# 2      MANUTENÇÃO E EXECUÇÃO DOS SERVIÇOS TÉCNICOS, A...
# 3      MANUTENÇÃO E EXECUÇÃO DOS SERVIÇOS TÉCNICOS, A...
# 4      MANUTENÇÃO E EXECUÇÃO DOS SERVIÇOS TÉCNICOS, A...
# ...                                                  ...
# 36081  TRANSFERÊNCIA DE RECURSOS ÀS ENTIDADES PRIVADA...
# 36082  TRANSFERÊNCIA DE RECURSOS ÀS ENTIDADES PRIVADA...
# 36083  TRANSFERÊNCIA DE RECURSOS ÀS ENTIDADES PRIVADA...
# 36084  PROMOÇÃO DA ASSISTÊNCIA GERAL AO SERVIDOR, CON...
# 36085            MANUTENÇÃO DA ESTRUTURA FUNCIONAL SME
#
#                                              SUBELEMENTO  \
# 0      LOCAÇÃO DE BENS MÓVEIS E OUTRAS NATUREZAS E IN...
# 1      LOCAÇÃO DE BENS MÓVEIS E OUTRAS NATUREZAS E IN...
# 2                        SERVIÇOS TÉCNICOS PROFISSIONAIS
# 3                        SERVIÇOS TÉCNICOS PROFISSIONAIS
# 4                        SERVIÇOS TÉCNICOS PROFISSIONAIS
# ...                                                  ...
# 36081  DEMAIS ENTIDADES DO TERCEIRO SETOR P/ PROMOÇÃO...
# 36082  DEMAIS ENTIDADES DO TERCEIRO SETOR P/ PROMOÇÃO...
# 36083  DEMAIS ENTIDADES DO TERCEIRO SETOR P/ PROMOÇÃO...
# 36084                                    AUXÍLIO-FUNERAL
# 36085                                   SEGUROS EM GERAL
#
#                                                    ORGAO  \
# 0                 FUNDO MUNICIPAL DE APOIO AO DEFICIENTE
# 1                 FUNDO MUNICIPAL DE APOIO AO DEFICIENTE
# 2       FUNDO MUNICIPAL DE HABITAÇÃO DE INTERESSE SOCIAL
# 3       FUNDO MUNICIPAL DE HABITAÇÃO DE INTERESSE SOCIAL
# 4       FUNDO MUNICIPAL DE HABITAÇÃO DE INTERESSE SOCIAL
# ...                                                  ...
# 36081                   SECRETARIA MUNICIPAL DA EDUCAÇÃO
# 36082                   SECRETARIA MUNICIPAL DA EDUCAÇÃO
# 36083                   SECRETARIA MUNICIPAL DA EDUCAÇÃO
# 36084  SECRETARIA MUNICIPAL DE ADMINISTRAÇÃO, GESTÃO ...
# 36085                   SECRETARIA MUNICIPAL DA EDUCAÇÃO
#
#                                                     TIPO  \
# 0         OUTROS SERVIÇOS DE TERCEIROS - PESSOA JURÍDICA
# 1         OUTROS SERVIÇOS DE TERCEIROS - PESSOA JURÍDICA
# 2         OUTROS SERVIÇOS DE TERCEIROS - PESSOA JURÍDICA
# 3         OUTROS SERVIÇOS DE TERCEIROS - PESSOA JURÍDICA
# 4         OUTROS SERVIÇOS DE TERCEIROS - PESSOA JURÍDICA
# ...                                                  ...
# 36081                                      CONTRIBUIÇÕES
# 36082                                      CONTRIBUIÇÕES
# 36083                                      CONTRIBUIÇÕES
# 36084  OUTROS  BENEFÍCIOS  ASSISTENCIAIS  DO  SERVIDO...
# 36085     OUTROS SERVIÇOS DE TERCEIROS - PESSOA JURÍDICA
#
#                                              ELEMENTO       DOCUMENTO  \
# 0      Outros Serviços de Terceiros - Pessoa Jurídica  33038864000151
# 1      Outros Serviços de Terceiros - Pessoa Jurídica  33038864000151
# 2      Outros Serviços de Terceiros - Pessoa Jurídica  03864060000140
# 3      Outros Serviços de Terceiros - Pessoa Jurídica  03864060000140
# 4      Outros Serviços de Terceiros - Pessoa Jurídica  03864060000140
# ...                                               ...             ...
# 36081                                   Contribuições  05803469000182
# 36082                                   Contribuições  06901226000140
# 36083                                   Contribuições  05680653000182
# 36084                 Outros Benefícios Assistenciais     92049168934
# 36085  Outros Serviços de Terceiros - Pessoa Jurídica  02964393000189
#
#        VALOR_EMPENHADO                                               ITEM  \
# 0              5103.00  BRINQUEDO INFLÁVEL, LOCAÇÃO,  PULA PULA, CASTE...
# 1              5103.00      BRINQUEDO,  PISCINA DE BOLINHAS CONVENCIONAL,
# 2              1665.88                                                NaN
# 3              1665.88                                                NaN
# 4              1665.88                                                NaN
# ...                ...                                                ...
# 36081          3496.00                                                NaN
# 36082          2136.00                                                NaN
# 36083          2684.00                                                NaN
# 36084          2050.00                                                NaN
# 36085           806.40                                                NaN
#
#       UNIDADE_ITEM  QUANTIDADE_ITEM  VALOR_PRECO_UNITARIO  VALOR_TOTAL  \
# 0              MO               3.0                 705.0       2115.0
# 1              MO               2.0                 402.0        804.0
# 2              NaN              0.0                   0.0          0.0
# 3              NaN              0.0                   0.0          0.0
# 4              NaN              0.0                   0.0          0.0
# ...            ...              ...                   ...          ...
# 36081          NaN              0.0                   0.0          0.0
# 36082          NaN              0.0                   0.0          0.0
# 36083          NaN              0.0                   0.0          0.0
# 36084          NaN              0.0                   0.0          0.0
# 36085          NaN              0.0                   0.0          0.0
#
#                 DATA_TRANSACAO       STATUS_TRANSACAO  VALOR_LIQUIDADO  \
# 0                          NaN                    NaN             0.00
# 1                          NaN                    NaN             0.00
# 2      2022-07-22 00:00:00.000     Anulado de Empenho             0.00
# 3      2022-07-14 00:00:00.000   Pagamento de Empenho             0.00
# 4      2022-07-13 00:00:00.000  Liquidação de Empenho          1133.44
# ...                        ...                    ...              ...
# 36081                      NaN                    NaN             0.00
# 36082                      NaN                    NaN             0.00
# 36083                      NaN                    NaN             0.00
# 36084                      NaN                    NaN             0.00
# 36085                      NaN                    NaN             0.00
#
#        VALOR_DEVOLVIDO  VALOR_ANULADO  VALOR_PAGO  VALOR_CONSIGNADO
# 0                  0.0           0.00        0.00               0.0
# 1                  0.0           0.00        0.00               0.0
# 2                  0.0         532.44        0.00               0.0
# 3                  0.0           0.00     1133.44               0.0
# 4                  0.0           0.00        0.00               0.0
# ...                ...            ...         ...               ...
# 36081              0.0           0.00        0.00               0.0
# 36082              0.0           0.00        0.00               0.0
# 36083              0.0           0.00        0.00               0.0
# 36084              0.0           0.00        0.00               0.0
# 36085              0.0           0.00        0.00               0.0
#
# [36086 rows x 23 columns]

# %% [markdown]
# Análise de coluna **ITEM** e similares para tentar limpar e padronizar os dados da mesma, sendo que possuem pouca diferença a não ser no modo como foi escrito.

# %%
df_cleaned['ITEM'] = df_cleaned['ITEM'].fillna("SEM ITEM")
df_cleaned['UNIDADE_ITEM'] = df_cleaned['UNIDADE_ITEM'].fillna("SEM UNIDADE")
df_cleaned['STATUS_TRANSACAO'] = df_cleaned['STATUS_TRANSACAO'].fillna("SEM STATUS")
df_cleaned['DATA_TRANSACAO'] = df_cleaned['DATA_TRANSACAO'].fillna("SEM DATA")

df_cleaned['ITEM'].unique()
# Out:
# array(['BRINQUEDO INFLÁVEL, LOCAÇÃO,  PULA PULA, CASTELO INFLÁVEL, SERVIÇO DE LOCAÇÃO',
#        'BRINQUEDO,  PISCINA DE BOLINHAS CONVENCIONAL,', 'SEM ITEM', ...,
#        'BALANÇA,  DIGITAL DE BOLSO DE ALTA PRECISÃO, CARACTERÍSTICAS DO, MB/BALANÇA DE BOLSO',
#        'MEMÓRIA,  EPROM, PARA ELEVADOR,',
#        'ROLDANA,  EM NYLON, PARA ELEVADOR,'], dtype=object)

# %% [markdown]
# Limpeza de alguns itens.

# %%
df_cleaned['ITEM'] = df_cleaned['ITEM'].str.replace(r'^MEMÓRIA.*.PARA ELEVADOR', 'BALANÇA PARA ELEVADOR', regex=True)
df_cleaned['ITEM'] = df_cleaned['ITEM'].str.replace(r'^ROLDANA.*.PARA ELEVADOR', 'ROLDANA PARA ELEVADOR', regex=True)
df_cleaned['ITEM'] = df_cleaned['ITEM'].str.replace(r'^BRINQUEDO.*', 'BRINQUEDO', regex=True)
df_cleaned['ITEM'] = df_cleaned['ITEM'].str.replace(r'^AMBULÂNCIA.*', 'AMBULÂNCIA', regex=True)
df_cleaned['ITEM'] = df_cleaned['ITEM'].str.replace(r'^BALANÇA.*', 'BALANÇA', regex=True)
df_cleaned['ITEM'] = df_cleaned['ITEM'].str.replace(r'^CAMISA.*', 'CAMISA', regex=True)
df_cleaned['ITEM'] = df_cleaned['ITEM'].str.replace(r'^UNIFORME.*', 'UNIFORME', regex=True)
df_cleaned['ITEM'] = df_cleaned['ITEM'].str.replace(r'^CABINE.*.SANITÁRIA.*', 'CABINE SANITÁRIA', regex=True)
df_cleaned['ITEM'] = df_cleaned['ITEM'].str.replace(r'^FIO.*', 'BARBANTE', regex=True)
df_cleaned['ITEM'] = df_cleaned['ITEM'].str.replace(r'^LINHA.*', 'BARBANTE', regex=True)
df_cleaned['ITEM'] = df_cleaned['ITEM'].str.replace(r'^AGULHA.*', 'AGULHA', regex=True)
df_cleaned['ITEM'] = df_cleaned['ITEM'].str.replace(r'^TECIDO.*', 'TECIDO', regex=True)
df_cleaned['ITEM'] = df_cleaned['ITEM'].str.replace(r'^TELA.*.PARA PINTURA.*', 'TELA PARA PINTURA', regex=True)
df_cleaned['ITEM'] = df_cleaned['ITEM'].str.replace(r'^TINTA.*', 'TINTA', regex=True)
df_cleaned['ITEM'] = df_cleaned['ITEM'].str.replace(r'^PINCEL.*', 'PINCEL', regex=True)
df_cleaned['ITEM'] = df_cleaned['ITEM'].str.replace(r'^LOCAÇÃO.*', 'LOCAÇÃO', regex=True)
df_cleaned['ITEM'] = df_cleaned['ITEM'].str.replace(r'^ESTRUTURA METÁLICA.*', 'LOCAÇÃO', regex=True)
df_cleaned['ITEM'] = df_cleaned['ITEM'].str.replace(r'^RECARGA.*.EXTINTOR.*', 'RECARGA DE EXTINTOR', regex=True)
df_cleaned['ITEM'] = df_cleaned['ITEM'].str.replace(r'^PLACA.*.SINALIZAÇÃO.*', 'PLACA DE SINALIZAÇÃO', regex=True)
df_cleaned['ITEM'] = df_cleaned['ITEM'].str.replace(r'^SUPORTE.*.EXTINTOR.*', 'SUPORTE DE EXTINTOR', regex=True)
df_cleaned['ITEM'] = df_cleaned['ITEM'].str.replace(r'^CERTIFICADO.*', 'CERTIFICADO', regex=True)
df_cleaned['ITEM'] = df_cleaned['ITEM'].str.replace(r'^ETIQUETA.*', 'ETIQUETA', regex=True)
df_cleaned['ITEM'] = df_cleaned['ITEM'].str.replace(r'^CANETA.*', 'CANETA', regex=True)
df_cleaned['ITEM'] = df_cleaned['ITEM'].str.replace(r'^BORRACHA.*', 'BORRACHA', regex=True)
df_cleaned['ITEM'] = df_cleaned['ITEM'].str.replace(r'^PAPEL.*', 'PAPEL', regex=True)
df_cleaned['ITEM'] = df_cleaned['ITEM'].str.replace(r'^BLOCO.*.RECADO.*', 'BLOCO PARA RECADO', regex=True)
df_cleaned['ITEM'] = df_cleaned['ITEM'].str.replace(r'^BALÃO.*', 'BALÃO', regex=True)
df_cleaned['ITEM'] = df_cleaned['ITEM'].str.replace(r'^REFIL.*.COLA QUENTE.*', 'REFIL DE COLA QUENTE', regex=True)
df_cleaned['ITEM'] = df_cleaned['ITEM'].str.replace(r'^LÁPIS.*', 'LÁPIS', regex=True)
df_cleaned['ITEM'] = df_cleaned['ITEM'].str.replace(r'^SACO.*.PLÁSTICO.*', 'SACO PLÁSTICO', regex=True)
df_cleaned['ITEM'] = df_cleaned['ITEM'].str.replace(r'^APRESENTADOR.*', 'APRESENTADOR', regex=True)
df_cleaned['ITEM'] = df_cleaned['ITEM'].str.replace(r'^MULTIMÍDIA.*', 'MULTIMÍDIA', regex=True)
df_cleaned['ITEM'] = df_cleaned['ITEM'].str.replace(r'^CABO.*.HDMI.*', 'CABO HDMI', regex=True)
df_cleaned['ITEM'] = df_cleaned['ITEM'].str.replace(r'^CARTUCHO.*.TINTA.*', 'CARTUCHO TINTA', regex=True)
df_cleaned['ITEM'] = df_cleaned['ITEM'].str.replace(r'^CADEIRA.*', 'CADEIRA', regex=True)
df_cleaned['ITEM'] = df_cleaned['ITEM'].str.replace(r'^PORTA.*', 'PORTA', regex=True)
df_cleaned['ITEM'] = df_cleaned['ITEM'].str.replace(r'^VIDRO.*', 'VIDRO', regex=True)
df_cleaned['ITEM'] = df_cleaned['ITEM'].str.replace(r'^DO IPPUC.*', 'OUTROS', regex=True)
df_cleaned['ITEM'] = df_cleaned['ITEM'].str.replace(r'^FECAHDURA.*', 'FECAHDURA', regex=True)
df_cleaned['ITEM'] = df_cleaned['ITEM'].str.replace(r'^ÁGUA.*', 'ÁGUA', regex=True)
df_cleaned['ITEM'] = df_cleaned['ITEM'].str.replace(r'^SONDAGEM.*', 'SONDAGEM', regex=True)
df_cleaned['ITEM'] = df_cleaned['ITEM'].str.replace(r'^LEVANTAMENTO PLANIALTIMÉTRICO.*', 'LEVANTAMENTO PLANIALTIMÉTRICO', regex=True)
df_cleaned['ITEM'] = df_cleaned['ITEM'].str.replace(r'^CONDULETE.*', 'CONDULETE', regex=True)
df_cleaned['ITEM'] = df_cleaned['ITEM'].str.replace(r'^TAMPA.*.CONDULETE.*', 'TAMPA PARA CONDULETE', regex=True)
df_cleaned['ITEM'] = df_cleaned['ITEM'].str.replace(r'^ELETRODUTO.*', 'ELETRODUTO', regex=True)
df_cleaned['ITEM'] = df_cleaned['ITEM'].str.replace(r'^LUVA.*', 'LUVA', regex=True)
df_cleaned['ITEM'] = df_cleaned['ITEM'].str.replace(r'^CORREDOR.*', 'CORREDOR', regex=True)
df_cleaned['ITEM'] = df_cleaned['ITEM'].str.replace(r'^DA INEXIGIBILIDADE.*', 'OUTROS', regex=True)
df_cleaned['ITEM'] = df_cleaned['ITEM'].str.replace(r'^LENÇO.*', 'LENÇO', regex=True)
df_cleaned['ITEM'] = df_cleaned['ITEM'].str.replace(r'^ELÁSTICO.*', 'ELÁSTICO', regex=True)
df_cleaned['ITEM'] = df_cleaned['ITEM'].str.replace(r'^PERCEVEJO.*', 'PERCEVEJO', regex=True)
df_cleaned['ITEM'] = df_cleaned['ITEM'].str.replace(r'^GRAMPO.*', 'GRAMPO', regex=True)
df_cleaned['ITEM'] = df_cleaned['ITEM'].str.replace(r'^TESOURA.*', 'TESOURA', regex=True)
df_cleaned['ITEM'] = df_cleaned['ITEM'].str.replace(r'^CORRETIVO.*', 'CORRETIVO', regex=True)
df_cleaned['ITEM'] = df_cleaned['ITEM'].str.replace(r'^CLIPS.*', 'CLIPS', regex=True)
df_cleaned['ITEM'] = df_cleaned['ITEM'].str.replace(r'^ESTILETE.*', 'ESTILETE', regex=True)
df_cleaned['ITEM'] = df_cleaned['ITEM'].str.replace(r'^UMEDECEDOR.*', 'UMEDECEDOR', regex=True)
df_cleaned['ITEM'] = df_cleaned['ITEM'].str.replace(r'^VASSOURA.*', 'VASSOURA', regex=True)
df_cleaned['ITEM'] = df_cleaned['ITEM'].str.replace(r'^CHÁ.*', 'CHÁ', regex=True)

df_cleaned['ITEM'].unique()
# Out:
# array(['BRINQUEDO', 'SEM ITEM', 'AMBULÂNCIA', ..., 'CAMISA', 'BALANÇA',
#        'ROLDANA PARA ELEVADOR,'], dtype=object)

# %% [markdown]
# Vamos criar uma coluna para diferenciar tipos de documento que está ligado à despesa.

# %%
df_cleaned['DOCUMENTO_TIPO'] = df_cleaned['DOCUMENTO'].apply(lambda x: 'CPF' if len(x) == 11 else 'CNPJ' if len(x) == 14 else 'DESCONHECIDO')
df_cleaned
# Out:
#             DATA                                              FONTE  \
# 0     2022-06-09  Recursos Próprios do Fundo Municipal de Apoio ...
# 1     2022-06-09  Recursos Próprios do Fundo Municipal de Apoio ...
# 2     2022-06-23  Recursos Próprios do Fundo Municipal de Habita...
# 3     2022-06-23  Recursos Próprios do Fundo Municipal de Habita...
# 4     2022-06-23  Recursos Próprios do Fundo Municipal de Habita...
# ...          ...                                                ...
# 36081 2022-08-31  Programa Dinheiro Direto na Escola - PDDE - Ed...
# 36082 2022-08-31  Programa Dinheiro Direto na Escola - PDDE - Ed...
# 36083 2022-08-31  Programa Dinheiro Direto na Escola - PDDE - Ed...
# 36084 2022-08-31                       Recursos Ordinários (Livres)
# 36085 2022-08-31     5% Sobre Transferências Constitucionais FUNDEB
#
#                    FUNCAO                              PROGRAMA  \
# 0      ASSISTÊNCIA SOCIAL  PROGRAMA VIVA CURITIBA QUE NÃO DORME
# 1      ASSISTÊNCIA SOCIAL  PROGRAMA VIVA CURITIBA QUE NÃO DORME
# 2               HABITAÇÃO         PROGRAMA VIVA CURITIBA CIDADÃ
# 3               HABITAÇÃO         PROGRAMA VIVA CURITIBA CIDADÃ
# 4               HABITAÇÃO         PROGRAMA VIVA CURITIBA CIDADÃ
# ...                   ...                                   ...
# 36081            EDUCAÇÃO         PROGRAMA VIVA CURITIBA CIDADÃ
# 36082            EDUCAÇÃO         PROGRAMA VIVA CURITIBA CIDADÃ
# 36083            EDUCAÇÃO         PROGRAMA VIVA CURITIBA CIDADÃ
# 36084       ADMINISTRAÇÃO   PROGRAMA VIVA CURITIBA TRANSPARENTE
# 36085            EDUCAÇÃO         PROGRAMA VIVA CURITIBA CIDADÃ
#
#                                                     ACAO  \
# 0      DESENVOLVIMENTO E EXECUÇÃO DE AÇÕES DE ATENDIM...
# 1      DESENVOLVIMENTO E EXECUÇÃO DE AÇÕES DE ATENDIM...
# 2      MANUTENÇÃO E EXECUÇÃO DOS SERVIÇOS TÉCNICOS, A...
# 3      MANUTENÇÃO E EXECUÇÃO DOS SERVIÇOS TÉCNICOS, A...
# 4      MANUTENÇÃO E EXECUÇÃO DOS SERVIÇOS TÉCNICOS, A...
# ...                                                  ...
# 36081  TRANSFERÊNCIA DE RECURSOS ÀS ENTIDADES PRIVADA...
# 36082  TRANSFERÊNCIA DE RECURSOS ÀS ENTIDADES PRIVADA...
# 36083  TRANSFERÊNCIA DE RECURSOS ÀS ENTIDADES PRIVADA...
# 36084  PROMOÇÃO DA ASSISTÊNCIA GERAL AO SERVIDOR, CON...
# 36085            MANUTENÇÃO DA ESTRUTURA FUNCIONAL SME
#
#                                              SUBELEMENTO  \
# 0      LOCAÇÃO DE BENS MÓVEIS E OUTRAS NATUREZAS E IN...
# 1      LOCAÇÃO DE BENS MÓVEIS E OUTRAS NATUREZAS E IN...
# 2                        SERVIÇOS TÉCNICOS PROFISSIONAIS
# 3                        SERVIÇOS TÉCNICOS PROFISSIONAIS
# 4                        SERVIÇOS TÉCNICOS PROFISSIONAIS
# ...                                                  ...
# 36081  DEMAIS ENTIDADES DO TERCEIRO SETOR P/ PROMOÇÃO...
# 36082  DEMAIS ENTIDADES DO TERCEIRO SETOR P/ PROMOÇÃO...
# 36083  DEMAIS ENTIDADES DO TERCEIRO SETOR P/ PROMOÇÃO...
# 36084                                    AUXÍLIO-FUNERAL
# 36085                                   SEGUROS EM GERAL
#
#                                                    ORGAO  \
# 0                 FUNDO MUNICIPAL DE APOIO AO DEFICIENTE
# 1                 FUNDO MUNICIPAL DE APOIO AO DEFICIENTE
# 2       FUNDO MUNICIPAL DE HABITAÇÃO DE INTERESSE SOCIAL
# 3       FUNDO MUNICIPAL DE HABITAÇÃO DE INTERESSE SOCIAL
# 4       FUNDO MUNICIPAL DE HABITAÇÃO DE INTERESSE SOCIAL
# ...                                                  ...
# 36081                   SECRETARIA MUNICIPAL DA EDUCAÇÃO
# 36082                   SECRETARIA MUNICIPAL DA EDUCAÇÃO
# 36083                   SECRETARIA MUNICIPAL DA EDUCAÇÃO
# 36084  SECRETARIA MUNICIPAL DE ADMINISTRAÇÃO, GESTÃO ...
# 36085                   SECRETARIA MUNICIPAL DA EDUCAÇÃO
#
#                                                     TIPO  \
# 0         OUTROS SERVIÇOS DE TERCEIROS - PESSOA JURÍDICA
# 1         OUTROS SERVIÇOS DE TERCEIROS - PESSOA JURÍDICA
# 2         OUTROS SERVIÇOS DE TERCEIROS - PESSOA JURÍDICA
# 3         OUTROS SERVIÇOS DE TERCEIROS - PESSOA JURÍDICA
# 4         OUTROS SERVIÇOS DE TERCEIROS - PESSOA JURÍDICA
# ...                                                  ...
# 36081                                      CONTRIBUIÇÕES
# 36082                                      CONTRIBUIÇÕES
# 36083                                      CONTRIBUIÇÕES
# 36084  OUTROS  BENEFÍCIOS  ASSISTENCIAIS  DO  SERVIDO...
# 36085     OUTROS SERVIÇOS DE TERCEIROS - PESSOA JURÍDICA
#
#                                              ELEMENTO       DOCUMENTO  \
# 0      Outros Serviços de Terceiros - Pessoa Jurídica  33038864000151
# 1      Outros Serviços de Terceiros - Pessoa Jurídica  33038864000151
# 2      Outros Serviços de Terceiros - Pessoa Jurídica  03864060000140
# 3      Outros Serviços de Terceiros - Pessoa Jurídica  03864060000140
# 4      Outros Serviços de Terceiros - Pessoa Jurídica  03864060000140
# ...                                               ...             ...
# 36081                                   Contribuições  05803469000182
# 36082                                   Contribuições  06901226000140
# 36083                                   Contribuições  05680653000182
# 36084                 Outros Benefícios Assistenciais     92049168934
# 36085  Outros Serviços de Terceiros - Pessoa Jurídica  02964393000189
#
#        VALOR_EMPENHADO       ITEM UNIDADE_ITEM  QUANTIDADE_ITEM  \
# 0              5103.00  BRINQUEDO          MO               3.0
# 1              5103.00  BRINQUEDO          MO               2.0
# 2              1665.88   SEM ITEM  SEM UNIDADE              0.0
# 3              1665.88   SEM ITEM  SEM UNIDADE              0.0
# 4              1665.88   SEM ITEM  SEM UNIDADE              0.0
# ...                ...        ...          ...              ...
# 36081          3496.00   SEM ITEM  SEM UNIDADE              0.0
# 36082          2136.00   SEM ITEM  SEM UNIDADE              0.0
# 36083          2684.00   SEM ITEM  SEM UNIDADE              0.0
# 36084          2050.00   SEM ITEM  SEM UNIDADE              0.0
# 36085           806.40   SEM ITEM  SEM UNIDADE              0.0
#
#        VALOR_PRECO_UNITARIO  VALOR_TOTAL           DATA_TRANSACAO  \
# 0                     705.0       2115.0                 SEM DATA
# 1                     402.0        804.0                 SEM DATA
# 2                       0.0          0.0  2022-07-22 00:00:00.000
# 3                       0.0          0.0  2022-07-14 00:00:00.000
# 4                       0.0          0.0  2022-07-13 00:00:00.000
# ...                     ...          ...                      ...
# 36081                   0.0          0.0                 SEM DATA
# 36082                   0.0          0.0                 SEM DATA
# 36083                   0.0          0.0                 SEM DATA
# 36084                   0.0          0.0                 SEM DATA
# 36085                   0.0          0.0                 SEM DATA
#
#             STATUS_TRANSACAO  VALOR_LIQUIDADO  VALOR_DEVOLVIDO  VALOR_ANULADO  \
# 0                 SEM STATUS             0.00              0.0           0.00
# 1                 SEM STATUS             0.00              0.0           0.00
# 2         Anulado de Empenho             0.00              0.0         532.44
# 3       Pagamento de Empenho             0.00              0.0           0.00
# 4      Liquidação de Empenho          1133.44              0.0           0.00
# ...                      ...              ...              ...            ...
# 36081             SEM STATUS             0.00              0.0           0.00
# 36082             SEM STATUS             0.00              0.0           0.00
# 36083             SEM STATUS             0.00              0.0           0.00
# 36084             SEM STATUS             0.00              0.0           0.00
# 36085             SEM STATUS             0.00              0.0           0.00
#
#        VALOR_PAGO  VALOR_CONSIGNADO DOCUMENTO_TIPO
# 0            0.00               0.0           CNPJ
# 1            0.00               0.0           CNPJ
# 2            0.00               0.0           CNPJ
# 3         1133.44               0.0           CNPJ
# 4            0.00               0.0           CNPJ
# ...           ...               ...            ...
# 36081        0.00               0.0           CNPJ
# 36082        0.00               0.0           CNPJ
# 36083        0.00               0.0           CNPJ
# 36084        0.00               0.0            CPF
# 36085        0.00               0.0           CNPJ
#
# [36086 rows x 24 columns]

# %% [markdown]
# Precisamos verificar se há despesas com documento desconhecido e entender se podemos tirar.

# %%
df_cleaned = df_cleaned[df_cleaned['DOCUMENTO_TIPO'] != 'DESCONHECIDO']
df_cleaned
# Out:
#             DATA                                              FONTE  \
# 0     2022-06-09  Recursos Próprios do Fundo Municipal de Apoio ...
# 1     2022-06-09  Recursos Próprios do Fundo Municipal de Apoio ...
# 2     2022-06-23  Recursos Próprios do Fundo Municipal de Habita...
# 3     2022-06-23  Recursos Próprios do Fundo Municipal de Habita...
# 4     2022-06-23  Recursos Próprios do Fundo Municipal de Habita...
# ...          ...                                                ...
# 36081 2022-08-31  Programa Dinheiro Direto na Escola - PDDE - Ed...
# 36082 2022-08-31  Programa Dinheiro Direto na Escola - PDDE - Ed...
# 36083 2022-08-31  Programa Dinheiro Direto na Escola - PDDE - Ed...
# 36084 2022-08-31                       Recursos Ordinários (Livres)
# 36085 2022-08-31     5% Sobre Transferências Constitucionais FUNDEB
#
#                    FUNCAO                              PROGRAMA  \
# 0      ASSISTÊNCIA SOCIAL  PROGRAMA VIVA CURITIBA QUE NÃO DORME
# 1      ASSISTÊNCIA SOCIAL  PROGRAMA VIVA CURITIBA QUE NÃO DORME
# 2               HABITAÇÃO         PROGRAMA VIVA CURITIBA CIDADÃ
# 3               HABITAÇÃO         PROGRAMA VIVA CURITIBA CIDADÃ
# 4               HABITAÇÃO         PROGRAMA VIVA CURITIBA CIDADÃ
# ...                   ...                                   ...
# 36081            EDUCAÇÃO         PROGRAMA VIVA CURITIBA CIDADÃ
# 36082            EDUCAÇÃO         PROGRAMA VIVA CURITIBA CIDADÃ
# 36083            EDUCAÇÃO         PROGRAMA VIVA CURITIBA CIDADÃ
# 36084       ADMINISTRAÇÃO   PROGRAMA VIVA CURITIBA TRANSPARENTE
# 36085            EDUCAÇÃO         PROGRAMA VIVA CURITIBA CIDADÃ
#
#                                                     ACAO  \
# 0      DESENVOLVIMENTO E EXECUÇÃO DE AÇÕES DE ATENDIM...
# 1      DESENVOLVIMENTO E EXECUÇÃO DE AÇÕES DE ATENDIM...
# 2      MANUTENÇÃO E EXECUÇÃO DOS SERVIÇOS TÉCNICOS, A...
# 3      MANUTENÇÃO E EXECUÇÃO DOS SERVIÇOS TÉCNICOS, A...
# 4      MANUTENÇÃO E EXECUÇÃO DOS SERVIÇOS TÉCNICOS, A...
# ...                                                  ...
# 36081  TRANSFERÊNCIA DE RECURSOS ÀS ENTIDADES PRIVADA...
# 36082  TRANSFERÊNCIA DE RECURSOS ÀS ENTIDADES PRIVADA...
# 36083  TRANSFERÊNCIA DE RECURSOS ÀS ENTIDADES PRIVADA...
# 36084  PROMOÇÃO DA ASSISTÊNCIA GERAL AO SERVIDOR, CON...
# 36085            MANUTENÇÃO DA ESTRUTURA FUNCIONAL SME
#
#                                              SUBELEMENTO  \
# 0      LOCAÇÃO DE BENS MÓVEIS E OUTRAS NATUREZAS E IN...
# 1      LOCAÇÃO DE BENS MÓVEIS E OUTRAS NATUREZAS E IN...
# 2                        SERVIÇOS TÉCNICOS PROFISSIONAIS
# 3                        SERVIÇOS TÉCNICOS PROFISSIONAIS
# 4                        SERVIÇOS TÉCNICOS PROFISSIONAIS
# ...                                                  ...
# 36081  DEMAIS ENTIDADES DO TERCEIRO SETOR P/ PROMOÇÃO...
# 36082  DEMAIS ENTIDADES DO TERCEIRO SETOR P/ PROMOÇÃO...
# 36083  DEMAIS ENTIDADES DO TERCEIRO SETOR P/ PROMOÇÃO...
# 36084                                    AUXÍLIO-FUNERAL
# 36085                                   SEGUROS EM GERAL
#
#                                                    ORGAO  \
# 0                 FUNDO MUNICIPAL DE APOIO AO DEFICIENTE
# 1                 FUNDO MUNICIPAL DE APOIO AO DEFICIENTE
# 2       FUNDO MUNICIPAL DE HABITAÇÃO DE INTERESSE SOCIAL
# 3       FUNDO MUNICIPAL DE HABITAÇÃO DE INTERESSE SOCIAL
# 4       FUNDO MUNICIPAL DE HABITAÇÃO DE INTERESSE SOCIAL
# ...                                                  ...
# 36081                   SECRETARIA MUNICIPAL DA EDUCAÇÃO
# 36082                   SECRETARIA MUNICIPAL DA EDUCAÇÃO
# 36083                   SECRETARIA MUNICIPAL DA EDUCAÇÃO
# 36084  SECRETARIA MUNICIPAL DE ADMINISTRAÇÃO, GESTÃO ...
# 36085                   SECRETARIA MUNICIPAL DA EDUCAÇÃO
#
#                                                     TIPO  \
# 0         OUTROS SERVIÇOS DE TERCEIROS - PESSOA JURÍDICA
# 1         OUTROS SERVIÇOS DE TERCEIROS - PESSOA JURÍDICA
# 2         OUTROS SERVIÇOS DE TERCEIROS - PESSOA JURÍDICA
# 3         OUTROS SERVIÇOS DE TERCEIROS - PESSOA JURÍDICA
# 4         OUTROS SERVIÇOS DE TERCEIROS - PESSOA JURÍDICA
# ...                                                  ...
# 36081                                      CONTRIBUIÇÕES
# 36082                                      CONTRIBUIÇÕES
# 36083                                      CONTRIBUIÇÕES
# 36084  OUTROS  BENEFÍCIOS  ASSISTENCIAIS  DO  SERVIDO...
# 36085     OUTROS SERVIÇOS DE TERCEIROS - PESSOA JURÍDICA
#
#                                              ELEMENTO       DOCUMENTO  \
# 0      Outros Serviços de Terceiros - Pessoa Jurídica  33038864000151
# 1      Outros Serviços de Terceiros - Pessoa Jurídica  33038864000151
# 2      Outros Serviços de Terceiros - Pessoa Jurídica  03864060000140
# 3      Outros Serviços de Terceiros - Pessoa Jurídica  03864060000140
# 4      Outros Serviços de Terceiros - Pessoa Jurídica  03864060000140
# ...                                               ...             ...
# 36081                                   Contribuições  05803469000182
# 36082                                   Contribuições  06901226000140
# 36083                                   Contribuições  05680653000182
# 36084                 Outros Benefícios Assistenciais     92049168934
# 36085  Outros Serviços de Terceiros - Pessoa Jurídica  02964393000189
#
#        VALOR_EMPENHADO       ITEM UNIDADE_ITEM  QUANTIDADE_ITEM  \
# 0              5103.00  BRINQUEDO          MO               3.0
# 1              5103.00  BRINQUEDO          MO               2.0
# 2              1665.88   SEM ITEM  SEM UNIDADE              0.0
# 3              1665.88   SEM ITEM  SEM UNIDADE              0.0
# 4              1665.88   SEM ITEM  SEM UNIDADE              0.0
# ...                ...        ...          ...              ...
# 36081          3496.00   SEM ITEM  SEM UNIDADE              0.0
# 36082          2136.00   SEM ITEM  SEM UNIDADE              0.0
# 36083          2684.00   SEM ITEM  SEM UNIDADE              0.0
# 36084          2050.00   SEM ITEM  SEM UNIDADE              0.0
# 36085           806.40   SEM ITEM  SEM UNIDADE              0.0
#
#        VALOR_PRECO_UNITARIO  VALOR_TOTAL           DATA_TRANSACAO  \
# 0                     705.0       2115.0                 SEM DATA
# 1                     402.0        804.0                 SEM DATA
# 2                       0.0          0.0  2022-07-22 00:00:00.000
# 3                       0.0          0.0  2022-07-14 00:00:00.000
# 4                       0.0          0.0  2022-07-13 00:00:00.000
# ...                     ...          ...                      ...
# 36081                   0.0          0.0                 SEM DATA
# 36082                   0.0          0.0                 SEM DATA
# 36083                   0.0          0.0                 SEM DATA
# 36084                   0.0          0.0                 SEM DATA
# 36085                   0.0          0.0                 SEM DATA
#
#             STATUS_TRANSACAO  VALOR_LIQUIDADO  VALOR_DEVOLVIDO  VALOR_ANULADO  \
# 0                 SEM STATUS             0.00              0.0           0.00
# 1                 SEM STATUS             0.00              0.0           0.00
# 2         Anulado de Empenho             0.00              0.0         532.44
# 3       Pagamento de Empenho             0.00              0.0           0.00
# 4      Liquidação de Empenho          1133.44              0.0           0.00
# ...                      ...              ...              ...            ...
# 36081             SEM STATUS             0.00              0.0           0.00
# 36082             SEM STATUS             0.00              0.0           0.00
# 36083             SEM STATUS             0.00              0.0           0.00
# 36084             SEM STATUS             0.00              0.0           0.00
# 36085             SEM STATUS             0.00              0.0           0.00
#
#        VALOR_PAGO  VALOR_CONSIGNADO DOCUMENTO_TIPO
# 0            0.00               0.0           CNPJ
# 1            0.00               0.0           CNPJ
# 2            0.00               0.0           CNPJ
# 3         1133.44               0.0           CNPJ
# 4            0.00               0.0           CNPJ
# ...           ...               ...            ...
# 36081        0.00               0.0           CNPJ
# 36082        0.00               0.0           CNPJ
# 36083        0.00               0.0           CNPJ
# 36084        0.00               0.0            CPF
# 36085        0.00               0.0           CNPJ
#
# [35981 rows x 24 columns]

# %% [markdown]
# Por fim, vamos ordenar as colunas manualmente de uma maneira que os dados relacionados fiquem mais próximos.

# %%
df_cleaned_columns = list(df_cleaned.columns)
df_cleaned_columns
# Out:
# ['DATA',
#  'FONTE',
#  'FUNCAO',
#  'PROGRAMA',
#  'ACAO',
#  'SUBELEMENTO',
#  'ORGAO',
#  'TIPO',
#  'ELEMENTO',
#  'DOCUMENTO',
#  'VALOR_EMPENHADO',
#  'ITEM',
#  'UNIDADE_ITEM',
#  'QUANTIDADE_ITEM',
#  'VALOR_PRECO_UNITARIO',
#  'VALOR_TOTAL',
#  'DATA_TRANSACAO',
#  'STATUS_TRANSACAO',
#  'VALOR_LIQUIDADO',
#  'VALOR_DEVOLVIDO',
#  'VALOR_ANULADO',
#  'VALOR_PAGO',
#  'VALOR_CONSIGNADO',
#  'DOCUMENTO_TIPO']

# %%
df_cleaned_columns = [
 'DATA',
 'FONTE',
 'FUNCAO',
 'TIPO',
 'ORGAO',
 'PROGRAMA',
 'ACAO',
 'ELEMENTO',
 'SUBELEMENTO',
 'DOCUMENTO',
 'DOCUMENTO_TIPO',
 'VALOR_EMPENHADO',
 'ITEM',
 'UNIDADE_ITEM',
 'QUANTIDADE_ITEM',
 'VALOR_PRECO_UNITARIO',
 'VALOR_TOTAL',
 'DATA_TRANSACAO',
 'STATUS_TRANSACAO',
 'VALOR_LIQUIDADO',
 'VALOR_DEVOLVIDO',
 'VALOR_ANULADO',
 'VALOR_PAGO',
 'VALOR_CONSIGNADO'
 ]
df_cleaned[df_cleaned_columns]
# Out:
#             DATA                                              FONTE  \
# 0     2022-06-09  Recursos Próprios do Fundo Municipal de Apoio ...
# 1     2022-06-09  Recursos Próprios do Fundo Municipal de Apoio ...
# 2     2022-06-23  Recursos Próprios do Fundo Municipal de Habita...
# 3     2022-06-23  Recursos Próprios do Fundo Municipal de Habita...
# 4     2022-06-23  Recursos Próprios do Fundo Municipal de Habita...
# ...          ...                                                ...
# 36081 2022-08-31  Programa Dinheiro Direto na Escola - PDDE - Ed...
# 36082 2022-08-31  Programa Dinheiro Direto na Escola - PDDE - Ed...
# 36083 2022-08-31  Programa Dinheiro Direto na Escola - PDDE - Ed...
# 36084 2022-08-31                       Recursos Ordinários (Livres)
# 36085 2022-08-31     5% Sobre Transferências Constitucionais FUNDEB
#
#                    FUNCAO                                               TIPO  \
# 0      ASSISTÊNCIA SOCIAL     OUTROS SERVIÇOS DE TERCEIROS - PESSOA JURÍDICA
# 1      ASSISTÊNCIA SOCIAL     OUTROS SERVIÇOS DE TERCEIROS - PESSOA JURÍDICA
# 2               HABITAÇÃO     OUTROS SERVIÇOS DE TERCEIROS - PESSOA JURÍDICA
# 3               HABITAÇÃO     OUTROS SERVIÇOS DE TERCEIROS - PESSOA JURÍDICA
# 4               HABITAÇÃO     OUTROS SERVIÇOS DE TERCEIROS - PESSOA JURÍDICA
# ...                   ...                                                ...
# 36081            EDUCAÇÃO                                      CONTRIBUIÇÕES
# 36082            EDUCAÇÃO                                      CONTRIBUIÇÕES
# 36083            EDUCAÇÃO                                      CONTRIBUIÇÕES
# 36084       ADMINISTRAÇÃO  OUTROS  BENEFÍCIOS  ASSISTENCIAIS  DO  SERVIDO...
# 36085            EDUCAÇÃO     OUTROS SERVIÇOS DE TERCEIROS - PESSOA JURÍDICA
#
#                                                    ORGAO  \
# 0                 FUNDO MUNICIPAL DE APOIO AO DEFICIENTE
# 1                 FUNDO MUNICIPAL DE APOIO AO DEFICIENTE
# 2       FUNDO MUNICIPAL DE HABITAÇÃO DE INTERESSE SOCIAL
# 3       FUNDO MUNICIPAL DE HABITAÇÃO DE INTERESSE SOCIAL
# 4       FUNDO MUNICIPAL DE HABITAÇÃO DE INTERESSE SOCIAL
# ...                                                  ...
# 36081                   SECRETARIA MUNICIPAL DA EDUCAÇÃO
# 36082                   SECRETARIA MUNICIPAL DA EDUCAÇÃO
# 36083                   SECRETARIA MUNICIPAL DA EDUCAÇÃO
# 36084  SECRETARIA MUNICIPAL DE ADMINISTRAÇÃO, GESTÃO ...
# 36085                   SECRETARIA MUNICIPAL DA EDUCAÇÃO
#
#                                    PROGRAMA  \
# 0      PROGRAMA VIVA CURITIBA QUE NÃO DORME
# 1      PROGRAMA VIVA CURITIBA QUE NÃO DORME
# 2             PROGRAMA VIVA CURITIBA CIDADÃ
# 3             PROGRAMA VIVA CURITIBA CIDADÃ
# 4             PROGRAMA VIVA CURITIBA CIDADÃ
# ...                                     ...
# 36081         PROGRAMA VIVA CURITIBA CIDADÃ
# 36082         PROGRAMA VIVA CURITIBA CIDADÃ
# 36083         PROGRAMA VIVA CURITIBA CIDADÃ
# 36084   PROGRAMA VIVA CURITIBA TRANSPARENTE
# 36085         PROGRAMA VIVA CURITIBA CIDADÃ
#
#                                                     ACAO  \
# 0      DESENVOLVIMENTO E EXECUÇÃO DE AÇÕES DE ATENDIM...
# 1      DESENVOLVIMENTO E EXECUÇÃO DE AÇÕES DE ATENDIM...
# 2      MANUTENÇÃO E EXECUÇÃO DOS SERVIÇOS TÉCNICOS, A...
# 3      MANUTENÇÃO E EXECUÇÃO DOS SERVIÇOS TÉCNICOS, A...
# 4      MANUTENÇÃO E EXECUÇÃO DOS SERVIÇOS TÉCNICOS, A...
# ...                                                  ...
# 36081  TRANSFERÊNCIA DE RECURSOS ÀS ENTIDADES PRIVADA...
# 36082  TRANSFERÊNCIA DE RECURSOS ÀS ENTIDADES PRIVADA...
# 36083  TRANSFERÊNCIA DE RECURSOS ÀS ENTIDADES PRIVADA...
# 36084  PROMOÇÃO DA ASSISTÊNCIA GERAL AO SERVIDOR, CON...
# 36085            MANUTENÇÃO DA ESTRUTURA FUNCIONAL SME
#
#                                              ELEMENTO  \
# 0      Outros Serviços de Terceiros - Pessoa Jurídica
# 1      Outros Serviços de Terceiros - Pessoa Jurídica
# 2      Outros Serviços de Terceiros - Pessoa Jurídica
# 3      Outros Serviços de Terceiros - Pessoa Jurídica
# 4      Outros Serviços de Terceiros - Pessoa Jurídica
# ...                                               ...
# 36081                                   Contribuições
# 36082                                   Contribuições
# 36083                                   Contribuições
# 36084                 Outros Benefícios Assistenciais
# 36085  Outros Serviços de Terceiros - Pessoa Jurídica
#
#                                              SUBELEMENTO       DOCUMENTO  \
# 0      LOCAÇÃO DE BENS MÓVEIS E OUTRAS NATUREZAS E IN...  33038864000151
# 1      LOCAÇÃO DE BENS MÓVEIS E OUTRAS NATUREZAS E IN...  33038864000151
# 2                        SERVIÇOS TÉCNICOS PROFISSIONAIS  03864060000140
# 3                        SERVIÇOS TÉCNICOS PROFISSIONAIS  03864060000140
# 4                        SERVIÇOS TÉCNICOS PROFISSIONAIS  03864060000140
# ...                                                  ...             ...
# 36081  DEMAIS ENTIDADES DO TERCEIRO SETOR P/ PROMOÇÃO...  05803469000182
# 36082  DEMAIS ENTIDADES DO TERCEIRO SETOR P/ PROMOÇÃO...  06901226000140
# 36083  DEMAIS ENTIDADES DO TERCEIRO SETOR P/ PROMOÇÃO...  05680653000182
# 36084                                    AUXÍLIO-FUNERAL     92049168934
# 36085                                   SEGUROS EM GERAL  02964393000189
#
#       DOCUMENTO_TIPO  VALOR_EMPENHADO       ITEM UNIDADE_ITEM  \
# 0               CNPJ          5103.00  BRINQUEDO          MO
# 1               CNPJ          5103.00  BRINQUEDO          MO
# 2               CNPJ          1665.88   SEM ITEM  SEM UNIDADE
# 3               CNPJ          1665.88   SEM ITEM  SEM UNIDADE
# 4               CNPJ          1665.88   SEM ITEM  SEM UNIDADE
# ...              ...              ...        ...          ...
# 36081           CNPJ          3496.00   SEM ITEM  SEM UNIDADE
# 36082           CNPJ          2136.00   SEM ITEM  SEM UNIDADE
# 36083           CNPJ          2684.00   SEM ITEM  SEM UNIDADE
# 36084            CPF          2050.00   SEM ITEM  SEM UNIDADE
# 36085           CNPJ           806.40   SEM ITEM  SEM UNIDADE
#
#        QUANTIDADE_ITEM  VALOR_PRECO_UNITARIO  VALOR_TOTAL  \
# 0                  3.0                 705.0       2115.0
# 1                  2.0                 402.0        804.0
# 2                  0.0                   0.0          0.0
# 3                  0.0                   0.0          0.0
# 4                  0.0                   0.0          0.0
# ...                ...                   ...          ...
# 36081              0.0                   0.0          0.0
# 36082              0.0                   0.0          0.0
# 36083              0.0                   0.0          0.0
# 36084              0.0                   0.0          0.0
# 36085              0.0                   0.0          0.0
#
#                 DATA_TRANSACAO       STATUS_TRANSACAO  VALOR_LIQUIDADO  \
# 0                     SEM DATA             SEM STATUS             0.00
# 1                     SEM DATA             SEM STATUS             0.00
# 2      2022-07-22 00:00:00.000     Anulado de Empenho             0.00
# 3      2022-07-14 00:00:00.000   Pagamento de Empenho             0.00
# 4      2022-07-13 00:00:00.000  Liquidação de Empenho          1133.44
# ...                        ...                    ...              ...
# 36081                 SEM DATA             SEM STATUS             0.00
# 36082                 SEM DATA             SEM STATUS             0.00
# 36083                 SEM DATA             SEM STATUS             0.00
# 36084                 SEM DATA             SEM STATUS             0.00
# 36085                 SEM DATA             SEM STATUS             0.00
#
#        VALOR_DEVOLVIDO  VALOR_ANULADO  VALOR_PAGO  VALOR_CONSIGNADO
# 0                  0.0           0.00        0.00               0.0
# 1                  0.0           0.00        0.00               0.0
# 2                  0.0         532.44        0.00               0.0
# 3                  0.0           0.00     1133.44               0.0
# 4                  0.0           0.00        0.00               0.0
# ...                ...            ...         ...               ...
# 36081              0.0           0.00        0.00               0.0
# 36082              0.0           0.00        0.00               0.0
# 36083              0.0           0.00        0.00               0.0
# 36084              0.0           0.00        0.00               0.0
# 36085              0.0           0.00        0.00               0.0
#
# [35981 rows x 24 columns]

# %% [markdown]
# # Salvando dados limpos

# %% [markdown]
# Para salvar os dados limpos em um arquivo, vamos usar o método to_csv

# %%
df_cleaned.to_csv('/content/drive/MyDrive/UP/Ciência de Dados/Notebooks/data/dataset_clean.csv', index=False, sep=';')
